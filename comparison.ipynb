# %%
from tf.app import use
SP = use("app:~/github/DT-UCPH/sp/app", locations="~/github/DT-UCPH/sp/tf", version="3.5.1", hoist=globals())
MT = use('etcbc/bhsa')
# Out:
# **Locating corpus resources ...**
#             <b>TF:</b> <a target="_blank" href="https://annotation.github.io/text-fabric/tf/cheatsheet.html" title="text-fabric api">TF API 12.5.1</a>, <a target="_blank" href="https://github.com///blob/master/app" title="app:~/github/DT-UCPH/sp/app app">//app  v3</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/tf/about/searchusage.html" title="Search Templates Introduction and Reference">Search Reference</a><br>
#             <b>Data:</b> <a target="_blank" href="https://etcbc.github.io/bhsa/" title="provenance of The Samaritan Pentateuch"> -  3.5.1</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/tf/writing/hebrew.html" title="How TF features represent text">Character table</a>, <a target="_blank" href="https://etcbc.github.io/bhsa/features/0_home" title=" -  feature documentation">Feature docs</a><br>
#             <details class="nodeinfo"><summary><b>Node types</b></summary>
# ...

# %% [markdown]
# ## December 23 experiment - Trying again to compare SP and MT text

# %% [markdown]
# #### SP text is different of MT text

# %%
text = """
book book=Deuteronomy|Deuteronomium
    chapter chapter=4
        verse verse=29
            word
"""
results_MT = MT.search(f'{text}')
results_SP = SP.search(f'{text}')
MT.show(results_MT, end=4, multiFeatures=False, queryFeatures=False, condensed=True, hiddenTypes={'phrase','half_verse','subphrase', 'sentence', 'sentence_atom', 'clause', 'clause_atom'})
SP.show(results_SP, end=4, multiFeatures=False, queryFeatures=False, condensed=True, withNodes=False)
# Out:
#   0.50s 18 results
#   0.11s 18 results
# <p><b>verse</b> <i>1</i>
# ...

# %%
text = """
book book=Deuteronomy|Deuteronomium
    chapter chapter=10
        verse verse=7
            word
"""
results_MT = MT.search(f'{text}')
results_SP = SP.search(f'{text}')
MT.show(results_MT, end=4, multiFeatures=False, queryFeatures=False, condensed=True, hiddenTypes={'phrase','half_verse','subphrase', 'sentence', 'sentence_atom', 'clause', 'clause_atom'})
SP.show(results_SP, end=4, multiFeatures=False, queryFeatures=False, condensed=True, withNodes=False)
# Out:
#   0.19s 13 results
#   0.10s 62 results
# <p><b>verse</b> <i>1</i>
# ...

# %%
text = """
book book=Deuteronomy|Deuteronomium
    chapter chapter=23
        verse verse=5
            word
"""
results_MT = MT.search(f'{text}')
results_SP = SP.search(f'{text}')
MT.show(results_MT, end=4, multiFeatures=False, queryFeatures=False, condensed=True, hiddenTypes={'phrase','half_verse','subphrase', 'sentence', 'sentence_atom', 'clause', 'clause_atom'})
SP.show(results_SP, end=4, multiFeatures=False, queryFeatures=False, condensed=True, withNodes=False)
# Out:
#   0.56s 34 results
#   0.05s 30 results
# <p><b>verse</b> <i>1</i>
# ...

# %%
text = """
book book=Deuteronomy|Deuteronomium
    chapter chapter=25
        verse verse=5
            word
"""
results_MT = MT.search(f'{text}')
results_SP = SP.search(f'{text}')
MT.show(results_MT, end=4, multiFeatures=False, queryFeatures=False, condensed=True, hiddenTypes={'phrase','half_verse','subphrase', 'sentence', 'sentence_atom', 'clause', 'clause_atom'})
SP.show(results_SP, end=4, multiFeatures=False, queryFeatures=False, condensed=True, withNodes=False)
# Out:
#   0.50s 32 results
#   0.09s 32 results
# <p><b>verse</b> <i>1</i>
# ...

# %%
text = """
book book=Deuteronomy|Deuteronomium
    chapter chapter=26
        verse verse=5
            word
"""
results_MT = MT.search(f'{text}')
results_SP = SP.search(f'{text}')
MT.show(results_MT, end=4, multiFeatures=False, queryFeatures=False, condensed=True, hiddenTypes={'phrase','half_verse','subphrase', 'sentence', 'sentence_atom', 'clause', 'clause_atom'})
SP.show(results_SP, end=4, multiFeatures=False, queryFeatures=False, condensed=True, withNodes=False)
# Out:
#   0.54s 29 results
#   0.09s 30 results
# <p><b>verse</b> <i>1</i>
# ...

# %%
#similar result
text = """
book book=Deuteronomy|Deuteronomium
    chapter chapter=27
        verse verse=4
            word
"""
results_MT = MT.search(f'{text}')
results_SP = SP.search(f'{text}')
MT.show(results_MT, end=4, multiFeatures=False, queryFeatures=False, condensed=True, hiddenTypes={'phrase','half_verse','subphrase', 'sentence', 'sentence_atom', 'clause', 'clause_atom'})
SP.show(results_SP, end=4, multiFeatures=False, queryFeatures=False, condensed=True, withNodes=False)
# Out:
#   0.51s 28 results
#   0.10s 26 results
# <p><b>verse</b> <i>1</i>
# ...

# %%
#similar result
text = """
book book=Exodus
    chapter chapter=8
        verse verse=12
            word
"""
results_MT = MT.search(f'{text}')
results_SP = SP.search(f'{text}')
MT.show(results_MT, end=4, multiFeatures=False, queryFeatures=False, condensed=True, hiddenTypes={'phrase','half_verse','subphrase', 'sentence', 'sentence_atom', 'clause', 'clause_atom'})
SP.show(results_SP, end=4, multiFeatures=False, queryFeatures=False, condensed=True, withNodes=False)
# Out:
#   0.49s 25 results
#   0.10s 27 results
# <p><b>verse</b> <i>1</i>
# ...

# %%
text = """
book book=Exodus
    chapter chapter=9
        verse verse=24
            word
"""
results_MT = MT.search(f'{text}')
results_SP = SP.search(f'{text}')
MT.show(results_MT, end=4, multiFeatures=False, queryFeatures=False, condensed=True, hiddenTypes={'phrase','half_verse','subphrase', 'sentence', 'sentence_atom', 'clause', 'clause_atom'})
SP.show(results_SP, end=4, multiFeatures=False, queryFeatures=False, condensed=True, withNodes=False)
# Out:
#   0.50s 25 results
#   0.09s 24 results
# <p><b>verse</b> <i>1</i>
# ...

# %%
#what is the condition to indicate that a vav will or will not divide a phrase atom?
text = """
book book=Exodus
    chapter chapter=10
        verse verse=24
            word
"""
results_MT = MT.search(f'{text}')
results_SP = SP.search(f'{text}')
MT.show(results_MT, end=4, multiFeatures=False, queryFeatures=False, condensed=True, hiddenTypes={'phrase','half_verse','subphrase', 'sentence', 'sentence_atom', 'clause', 'clause_atom'})
SP.show(results_SP, end=4, multiFeatures=False, queryFeatures=False, condensed=True, withNodes=False)
# Out:
#   0.19s 20 results
#   0.10s 23 results
# <p><b>verse</b> <i>1</i>
# ...

# %%
#similar result
text = """
book book=Exodus
    chapter chapter=14
        verse verse=12
            word
"""
results_MT = MT.search(f'{text}')
results_SP = SP.search(f'{text}')
MT.show(results_MT, end=4, multiFeatures=False, queryFeatures=False, condensed=True, hiddenTypes={'phrase','half_verse','subphrase', 'sentence', 'sentence_atom', 'clause', 'clause_atom'})
SP.show(results_SP, end=4, multiFeatures=False, queryFeatures=False, condensed=True, withNodes=False)
# Out:
#   0.50s 29 results
#   0.10s 29 results
# <p><b>verse</b> <i>1</i>
# ...

# %%
text = """
book book=Exodus
    chapter chapter=16
        verse verse=32
            word
"""
results_MT = MT.search(f'{text}')
results_SP = SP.search(f'{text}')
MT.show(results_MT, end=4, multiFeatures=False, queryFeatures=False, condensed=True, hiddenTypes={'phrase','half_verse','subphrase', 'sentence', 'sentence_atom', 'clause', 'clause_atom'})
SP.show(results_SP, end=4, multiFeatures=False, queryFeatures=False, condensed=True, withNodes=False)
# Out:
#   0.26s 34 results
#   0.06s 33 results
# <p><b>verse</b> <i>1</i>
# ...

# %%
text = """
book book=Exodus
    chapter chapter=22
        verse verse=11
            word
"""
results_MT = MT.search(f'{text}')
results_SP = SP.search(f'{text}')
MT.show(results_MT, end=4, multiFeatures=False, queryFeatures=False, condensed=True, hiddenTypes={'phrase','half_verse','subphrase', 'sentence', 'sentence_atom', 'clause', 'clause_atom'})
SP.show(results_SP, end=4, multiFeatures=False, queryFeatures=False, condensed=True, withNodes=False)
# Out:
#   0.52s 9 results
#   0.05s 9 results
# <p><b>verse</b> <i>1</i>
# ...

# %%
text = """
book book=Exodus
    chapter chapter=22
        verse verse=24
            word
"""
results_MT = MT.search(f'{text}')
results_SP = SP.search(f'{text}')
MT.show(results_MT, end=4, multiFeatures=False, queryFeatures=False, condensed=True, hiddenTypes={'phrase','half_verse','subphrase', 'sentence', 'sentence_atom', 'clause', 'clause_atom'})
SP.show(results_SP, end=4, multiFeatures=False, queryFeatures=False, condensed=True, withNodes=False)
# Out:
#   0.27s 18 results
#   0.10s 17 results
# <p><b>verse</b> <i>1</i>
# ...

# %%
text = """
book book=Exodus
    chapter chapter=22
        verse verse=29
            word
"""
results_MT = MT.search(f'{text}')
results_SP = SP.search(f'{text}')
MT.show(results_MT, end=4, multiFeatures=False, queryFeatures=False, condensed=True, hiddenTypes={'phrase','half_verse','subphrase', 'sentence', 'sentence_atom', 'clause', 'clause_atom'})
SP.show(results_SP, end=4, multiFeatures=False, queryFeatures=False, condensed=True, withNodes=False)
# Out:
#   0.51s 18 results
#   0.10s 19 results
# <p><b>verse</b> <i>1</i>
# ...

# %%
text = """
book book=Exodus
    chapter chapter=26
        verse verse=19
            word
"""
results_MT = MT.search(f'{text}')
results_SP = SP.search(f'{text}')
MT.show(results_MT, end=4, multiFeatures=False, queryFeatures=False, condensed=True, hiddenTypes={'phrase','half_verse','subphrase', 'sentence', 'sentence_atom', 'clause', 'clause_atom'})
SP.show(results_SP, end=4, multiFeatures=False, queryFeatures=False, condensed=True, withNodes=False)
# Out:
#   0.50s 30 results
#   0.10s 30 results
# <p><b>verse</b> <i>1</i>
# ...

# %%
#similar result
text = """
book book=Exodus
    chapter chapter=28
        verse verse=12
            word
"""
results_MT = MT.search(f'{text}')
results_SP = SP.search(f'{text}')
MT.show(results_MT, end=4, multiFeatures=False, queryFeatures=False, condensed=True, hiddenTypes={'phrase','half_verse','subphrase', 'sentence', 'sentence_atom', 'clause', 'clause_atom'})
SP.show(results_SP, end=4, multiFeatures=False, queryFeatures=False, condensed=True, withNodes=False)
# Out:
#   0.19s 28 results
#   0.05s 29 results
# <p><b>verse</b> <i>1</i>
# ...

# %%
text = """
book book=Exodus
    chapter chapter=38
        verse verse=9
            word
"""
results_MT = MT.search(f'{text}')
results_SP = SP.search(f'{text}')
MT.show(results_MT, end=4, multiFeatures=False, queryFeatures=False, condensed=True, hiddenTypes={'phrase','half_verse','subphrase', 'sentence', 'sentence_atom', 'clause', 'clause_atom'})
SP.show(results_SP, end=4, multiFeatures=False, queryFeatures=False, condensed=True, withNodes=False)
# Out:
#   0.55s 18 results
#   0.10s 17 results
# <p><b>verse</b> <i>1</i>
# ...

# %%
#should I add that at the end of each verse there is the end of a phrase atom?
text = """
book book=Exodus
    chapter chapter=38
        verse verse=25
            word
"""
results_MT = MT.search(f'{text}')
results_SP = SP.search(f'{text}')
MT.show(results_MT, end=4, multiFeatures=False, queryFeatures=False, condensed=True, hiddenTypes={'phrase','half_verse','subphrase', 'sentence', 'sentence_atom', 'clause', 'clause_atom'})
SP.show(results_SP, end=4, multiFeatures=False, queryFeatures=False, condensed=True, withNodes=False)
# Out:
#   0.49s 21 results
#   0.10s 17 results
# <p><b>verse</b> <i>1</i>
# ...

# %%
#similar result
#should I add that at the end of each verse there is the end of a phrase atom?
text = """
book book=Genesis
    chapter chapter=4
        verse verse=4
            word
"""
results_MT = MT.search(f'{text}')
results_SP = SP.search(f'{text}')
MT.show(results_MT, end=4, multiFeatures=False, queryFeatures=False, condensed=True, hiddenTypes={'phrase','half_verse','subphrase', 'sentence', 'sentence_atom', 'clause', 'clause_atom'})
SP.show(results_SP, end=4, multiFeatures=False, queryFeatures=False, condensed=True, withNodes=False)
# Out:
#   0.50s 19 results
#   0.05s 19 results
# <p><b>verse</b> <i>1</i>
# ...

# %%
text = """
book book=Genesis
    chapter chapter=19
        verse verse=28
            word
"""
results_MT = MT.search(f'{text}')
results_SP = SP.search(f'{text}')
MT.show(results_MT, end=4, multiFeatures=False, queryFeatures=False, condensed=True, hiddenTypes={'phrase','half_verse','subphrase', 'sentence', 'sentence_atom', 'clause', 'clause_atom'})
SP.show(results_SP, end=4, multiFeatures=False, queryFeatures=False, condensed=True, withNodes=False)
# Out:
#   0.19s 26 results
#   0.05s 27 results
# <p><b>verse</b> <i>1</i>
# ...

# %%
#similar result
text = """
book book=Genesis
    chapter chapter=21
        verse verse=8
            word
"""
results_MT = MT.search(f'{text}')
results_SP = SP.search(f'{text}')
MT.show(results_MT, end=4, multiFeatures=False, queryFeatures=False, condensed=True, hiddenTypes={'phrase','half_verse','subphrase', 'sentence', 'sentence_atom', 'clause', 'clause_atom'})
SP.show(results_SP, end=4, multiFeatures=False, queryFeatures=False, condensed=True, withNodes=False)
# Out:
#   0.54s 16 results
#   0.10s 17 results
# <p><b>verse</b> <i>1</i>
# ...

# %%
#similar result
text = """
book book=Genesis
    chapter chapter=25
        verse verse=17
            word
"""
results_MT = MT.search(f'{text}')
results_SP = SP.search(f'{text}')
MT.show(results_MT, end=4, multiFeatures=False, queryFeatures=False, condensed=True, hiddenTypes={'phrase','half_verse','subphrase', 'sentence', 'sentence_atom', 'clause', 'clause_atom'})
SP.show(results_SP, end=4, multiFeatures=False, queryFeatures=False, condensed=True, withNodes=False)
# Out:
#   0.22s 21 results
#   0.10s 22 results
# <p><b>verse</b> <i>1</i>
# ...

# %%
#similar result
text = """
book book=Genesis
    chapter chapter=31
        verse verse=35
            word
"""
results_MT = MT.search(f'{text}')
results_SP = SP.search(f'{text}')
MT.show(results_MT, end=4, multiFeatures=False, queryFeatures=False, condensed=True, hiddenTypes={'phrase','half_verse','subphrase', 'sentence', 'sentence_atom', 'clause', 'clause_atom'})
SP.show(results_SP, end=4, multiFeatures=False, queryFeatures=False, condensed=True, withNodes=False)
# Out:
#   0.20s 28 results
#   0.06s 29 results
# <p><b>verse</b> <i>1</i>
# ...

# %%
#similar result
#Is the ETCBC division of the words correct?
text = """
book book=Genesis
    chapter chapter=35
        verse verse=16
            word
"""
results_MT = MT.search(f'{text}')
results_SP = SP.search(f'{text}')
MT.show(results_MT, end=4, multiFeatures=False, queryFeatures=False, condensed=True, hiddenTypes={'phrase','half_verse','subphrase', 'sentence', 'sentence_atom', 'clause', 'clause_atom'})
SP.show(results_SP, end=4, multiFeatures=False, queryFeatures=False, condensed=True, withNodes=False)
# Out:
#   0.54s 20 results
#   0.05s 21 results
# <p><b>verse</b> <i>1</i>
# ...

# %%
text = """
book book=Genesis
    chapter chapter=35
        verse verse=22
            word
"""
results_MT = MT.search(f'{text}')
results_SP = SP.search(f'{text}')
MT.show(results_MT, end=4, multiFeatures=False, queryFeatures=False, condensed=True, hiddenTypes={'phrase','half_verse','subphrase', 'sentence', 'sentence_atom', 'clause', 'clause_atom'})
SP.show(results_SP, end=4, multiFeatures=False, queryFeatures=False, condensed=True, withNodes=False)
# Out:
#   0.52s 28 results
#   0.09s 27 results
# <p><b>verse</b> <i>1</i>
# ...

# %%
text = """
book book=Genesis
    chapter chapter=40
        verse verse=13
            word
"""
results_MT = MT.search(f'{text}')
results_SP = SP.search(f'{text}')
MT.show(results_MT, end=4, multiFeatures=False, queryFeatures=False, condensed=True, hiddenTypes={'phrase','half_verse','subphrase', 'sentence', 'sentence_atom', 'clause', 'clause_atom'})
SP.show(results_SP, end=4, multiFeatures=False, queryFeatures=False, condensed=True, withNodes=False)
# Out:
#   0.51s 26 results
#   0.10s 25 results
# <p><b>verse</b> <i>1</i>
# ...

# %%
text = """
book book=Genesis
    chapter chapter=47
        verse verse=6
            word
"""
results_MT = MT.search(f'{text}')
results_SP = SP.search(f'{text}')
MT.show(results_MT, end=4, multiFeatures=False, queryFeatures=False, condensed=True, hiddenTypes={'phrase','half_verse','subphrase', 'sentence', 'sentence_atom', 'clause', 'clause_atom'})
SP.show(results_SP, end=4, multiFeatures=False, queryFeatures=False, condensed=True, withNodes=False)
# Out:
#   0.60s 34 results
#   0.11s 34 results
# <p><b>verse</b> <i>1</i>
# ...

# %%
#what is the condition to indicate that a he will or will not divide a phrase atom?
text = """
book book=Leviticus
    chapter chapter=1
        verse verse=7
            word
"""
results_MT = MT.search(f'{text}')
results_SP = SP.search(f'{text}')
MT.show(results_MT, end=4, multiFeatures=False, queryFeatures=False, condensed=True, hiddenTypes={'phrase','half_verse','subphrase', 'sentence', 'sentence_atom', 'clause', 'clause_atom'})
SP.show(results_SP, end=4, multiFeatures=False, queryFeatures=False, condensed=True, withNodes=False)
# Out:
#   0.50s 16 results
#   0.09s 16 results
# <p><b>verse</b> <i>1</i>
# ...

# %%
#similar result
text = """
book book=Leviticus
    chapter chapter=3
        verse verse=10
            word
"""
results_MT = MT.search(f'{text}')
results_SP = SP.search(f'{text}')
MT.show(results_MT, end=4, multiFeatures=False, queryFeatures=False, condensed=True, hiddenTypes={'phrase','half_verse','subphrase', 'sentence', 'sentence_atom', 'clause', 'clause_atom'})
SP.show(results_SP, end=4, multiFeatures=False, queryFeatures=False, condensed=True, withNodes=False)
# Out:
#   0.50s 26 results
#   0.05s 26 results
# <p><b>verse</b> <i>1</i>
# ...

# %%
text = """
book book=Leviticus
    chapter chapter=7
        verse verse=8
            word
"""
results_MT = MT.search(f'{text}')
results_SP = SP.search(f'{text}')
MT.show(results_MT, end=4, multiFeatures=False, queryFeatures=False, condensed=True, hiddenTypes={'phrase','half_verse','subphrase', 'sentence', 'sentence_atom', 'clause', 'clause_atom'})
SP.show(results_SP, end=4, multiFeatures=False, queryFeatures=False, condensed=True, withNodes=False)
# Out:
#   0.19s 18 results
#   0.10s 17 results
# <p><b>verse</b> <i>1</i>
# ...

# %%
text = """
book book=Leviticus
    chapter chapter=8
        verse verse=24
            word
"""
results_MT = MT.search(f'{text}')
results_SP = SP.search(f'{text}')
MT.show(results_MT, end=4, multiFeatures=False, queryFeatures=False, condensed=True, hiddenTypes={'phrase','half_verse','subphrase', 'sentence', 'sentence_atom', 'clause', 'clause_atom'})
SP.show(results_SP, end=4, multiFeatures=False, queryFeatures=False, condensed=True, withNodes=False)
# Out:
#   0.51s 38 results
#   0.05s 38 results
# <p><b>verse</b> <i>1</i>
# ...

# %%
text = """
book book=Leviticus
    chapter chapter=8
        verse verse=30
            word
"""
results_MT = MT.search(f'{text}')
results_SP = SP.search(f'{text}')
MT.show(results_MT, end=4, multiFeatures=False, queryFeatures=False, condensed=True, hiddenTypes={'phrase','half_verse','subphrase', 'sentence', 'sentence_atom', 'clause', 'clause_atom'})
SP.show(results_SP, end=4, multiFeatures=False, queryFeatures=False, condensed=True, withNodes=False)
# Out:
#   0.19s 43 results
#   0.09s 45 results
# <p><b>verse</b> <i>1</i>
# ...

# %%
text = """
book book=Leviticus
    chapter chapter=10
        verse verse=12
            word
"""
results_MT = MT.search(f'{text}')
results_SP = SP.search(f'{text}')
MT.show(results_MT, end=4, multiFeatures=False, queryFeatures=False, condensed=True, hiddenTypes={'phrase','half_verse','subphrase', 'sentence', 'sentence_atom', 'clause', 'clause_atom'})
SP.show(results_SP, end=4, multiFeatures=False, queryFeatures=False, condensed=True, withNodes=False)
# Out:
#   0.53s 33 results
#   0.05s 33 results
# <p><b>verse</b> <i>1</i>
# ...

# %%
text = """
book book=Leviticus
    chapter chapter=11
        verse verse=28
            word
"""
results_MT = MT.search(f'{text}')
results_SP = SP.search(f'{text}')
MT.show(results_MT, end=4, multiFeatures=False, queryFeatures=False, condensed=True, hiddenTypes={'phrase','half_verse','subphrase', 'sentence', 'sentence_atom', 'clause', 'clause_atom'})
SP.show(results_SP, end=4, multiFeatures=False, queryFeatures=False, condensed=True, withNodes=False)
# Out:
#   0.19s 15 results
#   0.09s 15 results
# <p><b>verse</b> <i>1</i>
# ...

# %%
text = """
book book=Leviticus
    chapter chapter=14
        verse verse=22
            word
"""
results_MT = MT.search(f'{text}')
results_SP = SP.search(f'{text}')
MT.show(results_MT, end=4, multiFeatures=False, queryFeatures=False, condensed=True, hiddenTypes={'phrase','half_verse','subphrase', 'sentence', 'sentence_atom', 'clause', 'clause_atom'})
SP.show(results_SP, end=4, multiFeatures=False, queryFeatures=False, condensed=True, withNodes=False)
# Out:
#   0.50s 18 results
#   0.05s 17 results
# <p><b>verse</b> <i>1</i>
# ...

# %%
text = """
book book=Leviticus
    chapter chapter=24
        verse verse=7
            word
"""
results_MT = MT.search(f'{text}')
results_SP = SP.search(f'{text}')
MT.show(results_MT, end=4, multiFeatures=False, queryFeatures=False, condensed=True, hiddenTypes={'phrase','half_verse','subphrase', 'sentence', 'sentence_atom', 'clause', 'clause_atom'})
SP.show(results_SP, end=4, multiFeatures=False, queryFeatures=False, condensed=True, withNodes=False)
# Out:
#   0.53s 17 results
#   0.10s 16 results
# <p><b>verse</b> <i>1</i>
# ...

# %%
text = """
book book=Leviticus
    chapter chapter=27
        verse verse=33
            word
"""
results_MT = MT.search(f'{text}')
results_SP = SP.search(f'{text}')
MT.show(results_MT, end=4, multiFeatures=False, queryFeatures=False, condensed=True, hiddenTypes={'phrase','half_verse','subphrase', 'sentence', 'sentence_atom', 'clause', 'clause_atom'})
SP.show(results_SP, end=4, multiFeatures=False, queryFeatures=False, condensed=True, withNodes=False)
# Out:
#   0.18s 22 results
#   0.05s 22 results
# <p><b>verse</b> <i>1</i>
# ...

# %%
text = """
book book=Numbers|Numeri
    chapter chapter=3
        verse verse=21
            word
"""
results_MT = MT.search(f'{text}')
results_SP = SP.search(f'{text}')
MT.show(results_MT, end=4, multiFeatures=False, queryFeatures=False, condensed=True, hiddenTypes={'phrase','half_verse','subphrase', 'sentence', 'sentence_atom', 'clause', 'clause_atom'})
SP.show(results_SP, end=4, multiFeatures=False, queryFeatures=False, condensed=True, withNodes=False)
# Out:
#   0.54s 14 results
#   0.09s 14 results
# <p><b>verse</b> <i>1</i>
# ...

# %%
text = """
book book=Numbers|Numeri
    chapter chapter=14
        verse verse=24
            word
"""
results_MT = MT.search(f'{text}')
results_SP = SP.search(f'{text}')
MT.show(results_MT, end=4, multiFeatures=False, queryFeatures=False, condensed=True, hiddenTypes={'phrase','half_verse','subphrase', 'sentence', 'sentence_atom', 'clause', 'clause_atom'})
SP.show(results_SP, end=4, multiFeatures=False, queryFeatures=False, condensed=True, withNodes=False)
# Out:
#   0.58s 22 results
#   0.09s 22 results
# <p><b>verse</b> <i>1</i>
# ...

# %%
text = """
book book=Numbers|Numeri
    chapter chapter=14
        verse verse=29
            word
"""
results_MT = MT.search(f'{text}')
results_SP = SP.search(f'{text}')
MT.show(results_MT, end=4, multiFeatures=False, queryFeatures=False, condensed=True, hiddenTypes={'phrase','half_verse','subphrase', 'sentence', 'sentence_atom', 'clause', 'clause_atom'})
SP.show(results_SP, end=4, multiFeatures=False, queryFeatures=False, condensed=True, withNodes=False)
# Out:
#   0.19s 22 results
#   0.05s 21 results
# <p><b>verse</b> <i>1</i>
# ...

# %%
#similar result
text = """
book book=Numbers|Numeri
    chapter chapter=21
        verse verse=15
            word
"""
results_MT = MT.search(f'{text}')
results_SP = SP.search(f'{text}')
MT.show(results_MT, end=4, multiFeatures=False, queryFeatures=False, condensed=True, hiddenTypes={'phrase','half_verse','subphrase', 'sentence', 'sentence_atom', 'clause', 'clause_atom'})
SP.show(results_SP, end=4, multiFeatures=False, queryFeatures=False, condensed=True, withNodes=False)
# Out:
#   0.54s 14 results
#   0.10s 13 results
# <p><b>verse</b> <i>1</i>
# ...

# %%
#similar result
text = """
book book=Numbers|Numeri
    chapter chapter=26
        verse verse=30
            word
"""
results_MT = MT.search(f'{text}')
results_SP = SP.search(f'{text}')
MT.show(results_MT, end=4, multiFeatures=False, queryFeatures=False, condensed=True, hiddenTypes={'phrase','half_verse','subphrase', 'sentence', 'sentence_atom', 'clause', 'clause_atom'})
SP.show(results_SP, end=4, multiFeatures=False, queryFeatures=False, condensed=True, withNodes=False)
# Out:
#   0.18s 12 results
#   0.09s 12 results
# <p><b>verse</b> <i>1</i>
# ...

# %%
text = """
book book=Numbers|Numeri
    chapter chapter=26
        verse verse=50
            word
"""
results_MT = MT.search(f'{text}')
results_SP = SP.search(f'{text}')
MT.show(results_MT, end=4, multiFeatures=False, queryFeatures=False, condensed=True, hiddenTypes={'phrase','half_verse','subphrase', 'sentence', 'sentence_atom', 'clause', 'clause_atom'})
SP.show(results_SP, end=4, multiFeatures=False, queryFeatures=False, condensed=True, withNodes=False)
# Out:
#   0.51s 14 results
#   0.09s 14 results
# <p><b>verse</b> <i>1</i>
# ...

# %%
text = """
book book=Numbers|Numeri
    chapter chapter=28
        verse verse=13
            word
"""
results_MT = MT.search(f'{text}')
results_SP = SP.search(f'{text}')
MT.show(results_MT, end=4, multiFeatures=False, queryFeatures=False, condensed=True, hiddenTypes={'phrase','half_verse','subphrase', 'sentence', 'sentence_atom', 'clause', 'clause_atom'})
SP.show(results_SP, end=4, multiFeatures=False, queryFeatures=False, condensed=True, withNodes=False)
# Out:
#   0.51s 20 results
#   0.10s 18 results
# <p><b>verse</b> <i>1</i>
# ...

# %%
text = """
book book=Numbers|Numeri
    chapter chapter=34
        verse verse=7
            word
"""
results_MT = MT.search(f'{text}')
results_SP = SP.search(f'{text}')
MT.show(results_MT, end=4, multiFeatures=False, queryFeatures=False, condensed=True, hiddenTypes={'phrase','half_verse','subphrase', 'sentence', 'sentence_atom', 'clause', 'clause_atom'})
SP.show(results_SP, end=4, multiFeatures=False, queryFeatures=False, condensed=True, withNodes=False)
# Out:
#   0.51s 16 results
#   0.10s 16 results
# <p><b>verse</b> <i>1</i>
# ...

# %% [markdown]
# #### SP text is equal of MT text

# %%
text = """
book book=Deuteronomy|Deuteronomium
    chapter chapter=1
        verse verse=17
            word
"""
results_MT = MT.search(f'{text}')
results_SP = SP.search(f'{text}')
MT.show(results_MT, end=4, multiFeatures=False, queryFeatures=False, condensed=True, hiddenTypes={'phrase','half_verse','subphrase', 'sentence', 'sentence_atom', 'clause', 'clause_atom'})
SP.show(results_SP, end=4, multiFeatures=False, queryFeatures=False, condensed=True, withNodes=False)
# Out:
#   0.58s 34 results
#   0.10s 31 results
# <p><b>verse</b> <i>1</i>
# ...

# %%
text = """
book book=Deuteronomy|Deuteronomium
    chapter chapter=2
        verse verse=24
            word
"""
results_MT = MT.search(f'{text}')
results_SP = SP.search(f'{text}')
MT.show(results_MT, end=4, multiFeatures=False, queryFeatures=False, condensed=True, hiddenTypes={'phrase','half_verse','subphrase', 'sentence', 'sentence_atom', 'clause', 'clause_atom'})
SP.show(results_SP, end=4, multiFeatures=False, queryFeatures=False, condensed=True, withNodes=False)
# Out:
#   0.19s 26 results
#   0.05s 26 results
# <p><b>verse</b> <i>1</i>
# ...

# %%
text = """
book book=Deuteronomy|Deuteronomium
    chapter chapter=2
        verse verse=28
            word
"""
results_MT = MT.search(f'{text}')
results_SP = SP.search(f'{text}')
MT.show(results_MT, end=4, multiFeatures=False, queryFeatures=False, condensed=True, hiddenTypes={'phrase','half_verse','subphrase', 'sentence', 'sentence_atom', 'clause', 'clause_atom'})
SP.show(results_SP, end=4, multiFeatures=False, queryFeatures=False, condensed=True, withNodes=False)
# Out:
#   0.20s 20 results
#   0.05s 18 results
# <p><b>verse</b> <i>1</i>
# ...

# %%
text = """
book book=Deuteronomy|Deuteronomium
    chapter chapter=4
        verse verse=3
            word
"""
results_MT = MT.search(f'{text}')
results_SP = SP.search(f'{text}')
MT.show(results_MT, end=4, multiFeatures=False, queryFeatures=False, condensed=True, hiddenTypes={'phrase','half_verse','subphrase', 'sentence', 'sentence_atom', 'clause', 'clause_atom'})
SP.show(results_SP, end=4, multiFeatures=False, queryFeatures=False, condensed=True, withNodes=False)
# Out:
#   0.52s 22 results
#   0.05s 22 results
# <p><b>verse</b> <i>1</i>
# ...

# %%
text = """
book book=Deuteronomy|Deuteronomium
    chapter chapter=4
        verse verse=14
            word
"""
results_MT = MT.search(f'{text}')
results_SP = SP.search(f'{text}')
MT.show(results_MT, end=4, multiFeatures=False, queryFeatures=False, condensed=True, hiddenTypes={'phrase','half_verse','subphrase', 'sentence', 'sentence_atom', 'clause', 'clause_atom'})
SP.show(results_SP, end=4, multiFeatures=False, queryFeatures=False, condensed=True, withNodes=False)
# Out:
#   0.20s 27 results
#   0.10s 25 results
# <p><b>verse</b> <i>1</i>
# ...

# %%
text = """
book book=Deuteronomy|Deuteronomium
    chapter chapter=8
        verse verse=4
            word
"""
results_MT = MT.search(f'{text}')
results_SP = SP.search(f'{text}')
MT.show(results_MT, end=4, multiFeatures=False, queryFeatures=False, condensed=True, hiddenTypes={'phrase','half_verse','subphrase', 'sentence', 'sentence_atom', 'clause', 'clause_atom'})
SP.show(results_SP, end=4, multiFeatures=False, queryFeatures=False, condensed=True, withNodes=False)
# Out:
#   0.51s 12 results
#   0.09s 12 results
# <p><b>verse</b> <i>1</i>
# ...

# %%
text = """
book book=Deuteronomy|Deuteronomium
    chapter chapter=17
        verse verse=7
            word
"""
results_MT = MT.search(f'{text}')
results_SP = SP.search(f'{text}')
MT.show(results_MT, end=4, multiFeatures=False, queryFeatures=False, condensed=True, hiddenTypes={'phrase','half_verse','subphrase', 'sentence', 'sentence_atom', 'clause', 'clause_atom'})
SP.show(results_SP, end=4, multiFeatures=False, queryFeatures=False, condensed=True, withNodes=False)
# Out:
#   0.54s 24 results
#   0.10s 22 results
# <p><b>verse</b> <i>1</i>
# ...

# %%
text = """
book book=Deuteronomy|Deuteronomium
    chapter chapter=27
        verse verse=19
            word
"""
results_MT = MT.search(f'{text}')
results_SP = SP.search(f'{text}')
MT.show(results_MT, end=4, multiFeatures=False, queryFeatures=False, condensed=True, hiddenTypes={'phrase','half_verse','subphrase', 'sentence', 'sentence_atom', 'clause', 'clause_atom'})
SP.show(results_SP, end=4, multiFeatures=False, queryFeatures=False, condensed=True, withNodes=False)
# Out:
#   0.18s 13 results
#   0.10s 13 results
# <p><b>verse</b> <i>1</i>
# ...

# %%
text = """
book book=Deuteronomy|Deuteronomium
    chapter chapter=29
        verse verse=25
            word
"""
results_MT = MT.search(f'{text}')
results_SP = SP.search(f'{text}')
MT.show(results_MT, end=4, multiFeatures=False, queryFeatures=False, condensed=True, hiddenTypes={'phrase','half_verse','subphrase', 'sentence', 'sentence_atom', 'clause', 'clause_atom'})
SP.show(results_SP, end=4, multiFeatures=False, queryFeatures=False, condensed=True, withNodes=False)
# Out:
#   0.51s 17 results
#   0.09s 17 results
# <p><b>verse</b> <i>1</i>
# ...

# %%
text = """
book book=Exodus
    chapter chapter=2
        verse verse=11
            word
"""
results_MT = MT.search(f'{text}')
results_SP = SP.search(f'{text}')
MT.show(results_MT, end=4, multiFeatures=False, queryFeatures=False, condensed=True, hiddenTypes={'phrase','half_verse','subphrase', 'sentence', 'sentence_atom', 'clause', 'clause_atom'})
SP.show(results_SP, end=4, multiFeatures=False, queryFeatures=False, condensed=True, withNodes=False)
# Out:
#   0.50s 27 results
#   0.05s 26 results
# <p><b>verse</b> <i>1</i>
# ...

# %%
text = """
book book=Exodus
    chapter chapter=14
        verse verse=19
            word
"""
results_MT = MT.search(f'{text}')
results_SP = SP.search(f'{text}')
MT.show(results_MT, end=4, multiFeatures=False, queryFeatures=False, condensed=True, hiddenTypes={'phrase','half_verse','subphrase', 'sentence', 'sentence_atom', 'clause', 'clause_atom'})
SP.show(results_SP, end=4, multiFeatures=False, queryFeatures=False, condensed=True, withNodes=False)
# Out:
#   0.50s 26 results
#   0.10s 26 results
# <p><b>verse</b> <i>1</i>
# ...

# %%
text = """
book book=Exodus
    chapter chapter=21
        verse verse=19
            word
"""
results_MT = MT.search(f'{text}')
results_SP = SP.search(f'{text}')
MT.show(results_MT, end=4, multiFeatures=False, queryFeatures=False, condensed=True, hiddenTypes={'phrase','half_verse','subphrase', 'sentence', 'sentence_atom', 'clause', 'clause_atom'})
SP.show(results_SP, end=4, multiFeatures=False, queryFeatures=False, condensed=True, withNodes=False)
# Out:
#   0.53s 19 results
#   0.10s 18 results
# <p><b>verse</b> <i>1</i>
# ...

# %%
text = """
book book=Exodus
    chapter chapter=34
        verse verse=1
            word
"""
results_MT = MT.search(f'{text}')
results_SP = SP.search(f'{text}')
MT.show(results_MT, end=4, multiFeatures=False, queryFeatures=False, condensed=True, hiddenTypes={'phrase','half_verse','subphrase', 'sentence', 'sentence_atom', 'clause', 'clause_atom'})
SP.show(results_SP, end=4, multiFeatures=False, queryFeatures=False, condensed=True, withNodes=False)
# Out:
#   0.49s 30 results
#   0.10s 29 results
# <p><b>verse</b> <i>1</i>
# ...

# %%
text = """
book book=Exodus
    chapter chapter=36
        verse verse=22
            word
"""
results_MT = MT.search(f'{text}')
results_SP = SP.search(f'{text}')
MT.show(results_MT, end=4, multiFeatures=False, queryFeatures=False, condensed=True, hiddenTypes={'phrase','half_verse','subphrase', 'sentence', 'sentence_atom', 'clause', 'clause_atom'})
SP.show(results_SP, end=4, multiFeatures=False, queryFeatures=False, condensed=True, withNodes=False)
# Out:
#   0.19s 18 results
#   0.10s 17 results
# <p><b>verse</b> <i>1</i>
# ...

# %%
text = """
book book=Exodus
    chapter chapter=37
        verse verse=20
            word
"""
results_MT = MT.search(f'{text}')
results_SP = SP.search(f'{text}')
MT.show(results_MT, end=4, multiFeatures=False, queryFeatures=False, condensed=True, hiddenTypes={'phrase','half_verse','subphrase', 'sentence', 'sentence_atom', 'clause', 'clause_atom'})
SP.show(results_SP, end=4, multiFeatures=False, queryFeatures=False, condensed=True, withNodes=False)
# Out:
#   0.19s 10 results
#   0.10s 9 results
# <p><b>verse</b> <i>1</i>
# ...

# %%
text = """
book book=Exodus
    chapter chapter=40
        verse verse=34
            word
"""
results_MT = MT.search(f'{text}')
results_SP = SP.search(f'{text}')
MT.show(results_MT, end=4, multiFeatures=False, queryFeatures=False, condensed=True, hiddenTypes={'phrase','half_verse','subphrase', 'sentence', 'sentence_atom', 'clause', 'clause_atom'})
SP.show(results_SP, end=4, multiFeatures=False, queryFeatures=False, condensed=True, withNodes=False)
# Out:
#   0.51s 14 results
#   0.06s 14 results
# <p><b>verse</b> <i>1</i>
# ...

# %%
text = """
book book=Genesis
    chapter chapter=8
        verse verse=4
            word
"""
results_MT = MT.search(f'{text}')
results_SP = SP.search(f'{text}')
MT.show(results_MT, end=4, multiFeatures=False, queryFeatures=False, condensed=True, hiddenTypes={'phrase','half_verse','subphrase', 'sentence', 'sentence_atom', 'clause', 'clause_atom'})
SP.show(results_SP, end=4, multiFeatures=False, queryFeatures=False, condensed=True, withNodes=False)
# Out:
#   0.51s 19 results
#   0.10s 17 results
# <p><b>verse</b> <i>1</i>
# ...

# %%
text = """
book book=Genesis
    chapter chapter=14
        verse verse=14
            word
"""
results_MT = MT.search(f'{text}')
results_SP = SP.search(f'{text}')
MT.show(results_MT, end=4, multiFeatures=False, queryFeatures=False, condensed=True, hiddenTypes={'phrase','half_verse','subphrase', 'sentence', 'sentence_atom', 'clause', 'clause_atom'})
SP.show(results_SP, end=4, multiFeatures=False, queryFeatures=False, condensed=True, withNodes=False)
# Out:
#   0.20s 21 results
#   0.10s 21 results
# <p><b>verse</b> <i>1</i>
# ...

# %%
text = """
book book=Genesis
    chapter chapter=19
        verse verse=1
            word
"""
results_MT = MT.search(f'{text}')
results_SP = SP.search(f'{text}')
MT.show(results_MT, end=4, multiFeatures=False, queryFeatures=False, condensed=True, hiddenTypes={'phrase','half_verse','subphrase', 'sentence', 'sentence_atom', 'clause', 'clause_atom'})
SP.show(results_SP, end=4, multiFeatures=False, queryFeatures=False, condensed=True, withNodes=False)
# Out:
#   0.56s 26 results
#   0.09s 25 results
# <p><b>verse</b> <i>1</i>
# ...

# %%
text = """
book book=Genesis
    chapter chapter=24
        verse verse=17
            word
"""
results_MT = MT.search(f'{text}')
results_SP = SP.search(f'{text}')
MT.show(results_MT, end=4, multiFeatures=False, queryFeatures=False, condensed=True, hiddenTypes={'phrase','half_verse','subphrase', 'sentence', 'sentence_atom', 'clause', 'clause_atom'})
SP.show(results_SP, end=4, multiFeatures=False, queryFeatures=False, condensed=True, withNodes=False)
# Out:
#   0.53s 14 results
#   0.05s 14 results
# <p><b>verse</b> <i>1</i>
# ...

# %%
text = """
book book=Genesis
    chapter chapter=24
        verse verse=52
            word
"""
results_MT = MT.search(f'{text}')
results_SP = SP.search(f'{text}')
MT.show(results_MT, end=4, multiFeatures=False, queryFeatures=False, condensed=True, hiddenTypes={'phrase','half_verse','subphrase', 'sentence', 'sentence_atom', 'clause', 'clause_atom'})
SP.show(results_SP, end=4, multiFeatures=False, queryFeatures=False, condensed=True, withNodes=False)
# Out:
#   0.18s 14 results
#   0.05s 14 results
# <p><b>verse</b> <i>1</i>
# ...

# %%
text = """
book book=Genesis
    chapter chapter=27
        verse verse=45
            word
"""
results_MT = MT.search(f'{text}')
results_SP = SP.search(f'{text}')
MT.show(results_MT, end=4, multiFeatures=False, queryFeatures=False, condensed=True, hiddenTypes={'phrase','half_verse','subphrase', 'sentence', 'sentence_atom', 'clause', 'clause_atom'})
SP.show(results_SP, end=4, multiFeatures=False, queryFeatures=False, condensed=True, withNodes=False)
# Out:
#   0.19s 23 results
#   0.05s 23 results
# <p><b>verse</b> <i>1</i>
# ...

# %%
text = """
book book=Genesis
    chapter chapter=30
        verse verse=3
            word
"""
results_MT = MT.search(f'{text}')
results_SP = SP.search(f'{text}')
MT.show(results_MT, end=4, multiFeatures=False, queryFeatures=False, condensed=True, hiddenTypes={'phrase','half_verse','subphrase', 'sentence', 'sentence_atom', 'clause', 'clause_atom'})
SP.show(results_SP, end=4, multiFeatures=False, queryFeatures=False, condensed=True, withNodes=False)
# Out:
#   0.24s 16 results
#   0.11s 16 results
# <p><b>verse</b> <i>1</i>
# ...

# %%
text = """
book book=Genesis
    chapter chapter=33
        verse verse=12
            word
"""
results_MT = MT.search(f'{text}')
results_SP = SP.search(f'{text}')
MT.show(results_MT, end=4, multiFeatures=False, queryFeatures=False, condensed=True, hiddenTypes={'phrase','half_verse','subphrase', 'sentence', 'sentence_atom', 'clause', 'clause_atom'})
SP.show(results_SP, end=4, multiFeatures=False, queryFeatures=False, condensed=True, withNodes=False)
# Out:
#   0.52s 9 results
#   0.10s 9 results
# <p><b>verse</b> <i>1</i>
# ...

# %%
text = """
book book=Genesis
    chapter chapter=42
        verse verse=29
            word
"""
results_MT = MT.search(f'{text}')
results_SP = SP.search(f'{text}')
MT.show(results_MT, end=4, multiFeatures=False, queryFeatures=False, condensed=True, hiddenTypes={'phrase','half_verse','subphrase', 'sentence', 'sentence_atom', 'clause', 'clause_atom'})
SP.show(results_SP, end=4, multiFeatures=False, queryFeatures=False, condensed=True, withNodes=False)
# Out:
#   0.20s 17 results
#   0.06s 17 results
# <p><b>verse</b> <i>1</i>
# ...

# %%
text = """
book book=Genesis
    chapter chapter=43
        verse verse=21
            word
"""
results_MT = MT.search(f'{text}')
results_SP = SP.search(f'{text}')
MT.show(results_MT, end=4, multiFeatures=False, queryFeatures=False, condensed=True, hiddenTypes={'phrase','half_verse','subphrase', 'sentence', 'sentence_atom', 'clause', 'clause_atom'})
SP.show(results_SP, end=4, multiFeatures=False, queryFeatures=False, condensed=True, withNodes=False)
# Out:
#   0.54s 26 results
#   0.05s 26 results
# <p><b>verse</b> <i>1</i>
# ...

# %%
text = """
book book=Genesis
    chapter chapter=47
        verse verse=26
            word
"""
results_MT = MT.search(f'{text}')
results_SP = SP.search(f'{text}')
MT.show(results_MT, end=4, multiFeatures=False, queryFeatures=False, condensed=True, hiddenTypes={'phrase','half_verse','subphrase', 'sentence', 'sentence_atom', 'clause', 'clause_atom'})
SP.show(results_SP, end=4, multiFeatures=False, queryFeatures=False, condensed=True, withNodes=False)
# Out:
#   0.19s 29 results
#   0.10s 28 results
# <p><b>verse</b> <i>1</i>
# ...

# %%
text = """
book book=Leviticus
    chapter chapter=3
        verse verse=7
            word
"""
results_MT = MT.search(f'{text}')
results_SP = SP.search(f'{text}')
MT.show(results_MT, end=4, multiFeatures=False, queryFeatures=False, condensed=True, hiddenTypes={'phrase','half_verse','subphrase', 'sentence', 'sentence_atom', 'clause', 'clause_atom'})
SP.show(results_SP, end=4, multiFeatures=False, queryFeatures=False, condensed=True, withNodes=False)
# Out:
#   0.49s 12 results
#   0.09s 12 results
# <p><b>verse</b> <i>1</i>
# ...

# %%
text = """
book book=Leviticus
    chapter chapter=7
        verse verse=10
            word
"""
results_MT = MT.search(f'{text}')
results_SP = SP.search(f'{text}')
MT.show(results_MT, end=4, multiFeatures=False, queryFeatures=False, condensed=True, hiddenTypes={'phrase','half_verse','subphrase', 'sentence', 'sentence_atom', 'clause', 'clause_atom'})
SP.show(results_SP, end=4, multiFeatures=False, queryFeatures=False, condensed=True, withNodes=False)
# Out:
#   0.49s 17 results
#   0.10s 16 results
# <p><b>verse</b> <i>1</i>
# ...

# %%
text = """
book book=Leviticus
    chapter chapter=11
        verse verse=11
            word
"""
results_MT = MT.search(f'{text}')
results_SP = SP.search(f'{text}')
MT.show(results_MT, end=4, multiFeatures=False, queryFeatures=False, condensed=True, hiddenTypes={'phrase','half_verse','subphrase', 'sentence', 'sentence_atom', 'clause', 'clause_atom'})
SP.show(results_SP, end=4, multiFeatures=False, queryFeatures=False, condensed=True, withNodes=False)
# Out:
#   0.52s 12 results
#   0.05s 12 results
# <p><b>verse</b> <i>1</i>
# ...

# %%
text = """
book book=Leviticus
    chapter chapter=14
        verse verse=7
            word
"""
results_MT = MT.search(f'{text}')
results_SP = SP.search(f'{text}')
MT.show(results_MT, end=4, multiFeatures=False, queryFeatures=False, condensed=True, hiddenTypes={'phrase','half_verse','subphrase', 'sentence', 'sentence_atom', 'clause', 'clause_atom'})
SP.show(results_SP, end=4, multiFeatures=False, queryFeatures=False, condensed=True, withNodes=False)
# Out:
#   0.49s 23 results
#   0.10s 23 results
# <p><b>verse</b> <i>1</i>
# ...

# %%
text = """
book book=Leviticus
    chapter chapter=20
        verse verse=11
            word
"""
results_MT = MT.search(f'{text}')
results_SP = SP.search(f'{text}')
MT.show(results_MT, end=4, multiFeatures=False, queryFeatures=False, condensed=True, hiddenTypes={'phrase','half_verse','subphrase', 'sentence', 'sentence_atom', 'clause', 'clause_atom'})
SP.show(results_SP, end=4, multiFeatures=False, queryFeatures=False, condensed=True, withNodes=False)
# Out:
#   0.52s 15 results
#   0.05s 15 results
# <p><b>verse</b> <i>1</i>
# ...

# %%
text = """
book book=Leviticus
    chapter chapter=22
        verse verse=4
            word
"""
results_MT = MT.search(f'{text}')
results_SP = SP.search(f'{text}')
MT.show(results_MT, end=4, multiFeatures=False, queryFeatures=False, condensed=True, hiddenTypes={'phrase','half_verse','subphrase', 'sentence', 'sentence_atom', 'clause', 'clause_atom'})
SP.show(results_SP, end=4, multiFeatures=False, queryFeatures=False, condensed=True, withNodes=False)
# Out:
#   0.49s 32 results
#   0.10s 31 results
# <p><b>verse</b> <i>1</i>
# ...

# %%
text = """
book book=Leviticus
    chapter chapter=23
        verse verse=44
            word
"""
results_MT = MT.search(f'{text}')
results_SP = SP.search(f'{text}')
MT.show(results_MT, end=4, multiFeatures=False, queryFeatures=False, condensed=True, hiddenTypes={'phrase','half_verse','subphrase', 'sentence', 'sentence_atom', 'clause', 'clause_atom'})
SP.show(results_SP, end=4, multiFeatures=False, queryFeatures=False, condensed=True, withNodes=False)
# Out:
#   0.18s 9 results
#   0.05s 9 results
# <p><b>verse</b> <i>1</i>
# ...

# %%
text = """
book book=Leviticus
    chapter chapter=24
        verse verse=15
            word
"""
results_MT = MT.search(f'{text}')
results_SP = SP.search(f'{text}')
MT.show(results_MT, end=4, multiFeatures=False, queryFeatures=False, condensed=True, hiddenTypes={'phrase','half_verse','subphrase', 'sentence', 'sentence_atom', 'clause', 'clause_atom'})
SP.show(results_SP, end=4, multiFeatures=False, queryFeatures=False, condensed=True, withNodes=False)
# Out:
#   0.54s 15 results
#   0.09s 15 results
# <p><b>verse</b> <i>1</i>
# ...

# %%
text = """
book book=Leviticus
    chapter chapter=24
        verse verse=18
            word
"""
results_MT = MT.search(f'{text}')
results_SP = SP.search(f'{text}')
MT.show(results_MT, end=4, multiFeatures=False, queryFeatures=False, condensed=True, hiddenTypes={'phrase','half_verse','subphrase', 'sentence', 'sentence_atom', 'clause', 'clause_atom'})
SP.show(results_SP, end=4, multiFeatures=False, queryFeatures=False, condensed=True, withNodes=False)
# Out:
#   0.18s 8 results
#   0.09s 8 results
# <p><b>verse</b> <i>1</i>
# ...

# %%
text = """
book book=Leviticus
    chapter chapter=25
        verse verse=31
            word
"""
results_MT = MT.search(f'{text}')
results_SP = SP.search(f'{text}')
MT.show(results_MT, end=4, multiFeatures=False, queryFeatures=False, condensed=True, hiddenTypes={'phrase','half_verse','subphrase', 'sentence', 'sentence_atom', 'clause', 'clause_atom'})
SP.show(results_SP, end=4, multiFeatures=False, queryFeatures=False, condensed=True, withNodes=False)
# Out:
#   0.20s 22 results
#   0.05s 21 results
# <p><b>verse</b> <i>1</i>
# ...

# %%
text = """
book book=Leviticus
    chapter chapter=26
        verse verse=23
            word
"""
results_MT = MT.search(f'{text}')
results_SP = SP.search(f'{text}')
MT.show(results_MT, end=4, multiFeatures=False, queryFeatures=False, condensed=True, hiddenTypes={'phrase','half_verse','subphrase', 'sentence', 'sentence_atom', 'clause', 'clause_atom'})
SP.show(results_SP, end=4, multiFeatures=False, queryFeatures=False, condensed=True, withNodes=False)
# Out:
#   0.27s 11 results
#   0.05s 11 results
# <p><b>verse</b> <i>1</i>
# ...

# %%
text = """
book book=Numbers|Numeri
    chapter chapter=3
        verse verse=5
            word
"""
results_MT = MT.search(f'{text}')
results_SP = SP.search(f'{text}')
MT.show(results_MT, end=4, multiFeatures=False, queryFeatures=False, condensed=True, hiddenTypes={'phrase','half_verse','subphrase', 'sentence', 'sentence_atom', 'clause', 'clause_atom'})
SP.show(results_SP, end=4, multiFeatures=False, queryFeatures=False, condensed=True, withNodes=False)
# Out:
#   0.52s 7 results
#   0.10s 7 results
# <p><b>verse</b> <i>1</i>
# ...

# %%
text = """
book book=Numbers|Numeri
    chapter chapter=4
        verse verse=12
            word
"""
results_MT = MT.search(f'{text}')
results_SP = SP.search(f'{text}')
MT.show(results_MT, end=4, multiFeatures=False, queryFeatures=False, condensed=True, hiddenTypes={'phrase','half_verse','subphrase', 'sentence', 'sentence_atom', 'clause', 'clause_atom'})
SP.show(results_SP, end=4, multiFeatures=False, queryFeatures=False, condensed=True, withNodes=False)
# Out:
#   0.52s 30 results
#   0.10s 29 results
# <p><b>verse</b> <i>1</i>
# ...

# %%
text = """
book book=Numbers|Numeri
    chapter chapter=4
        verse verse=43
            word
"""
results_MT = MT.search(f'{text}')
results_SP = SP.search(f'{text}')
MT.show(results_MT, end=4, multiFeatures=False, queryFeatures=False, condensed=True, hiddenTypes={'phrase','half_verse','subphrase', 'sentence', 'sentence_atom', 'clause', 'clause_atom'})
SP.show(results_SP, end=4, multiFeatures=False, queryFeatures=False, condensed=True, withNodes=False)
# Out:
#   0.24s 22 results
#   0.07s 21 results
# <p><b>verse</b> <i>1</i>
# ...

# %%
text = """
book book=Numbers|Numeri
    chapter chapter=6
        verse verse=1
            word
"""
results_MT = MT.search(f'{text}')
results_SP = SP.search(f'{text}')
MT.show(results_MT, end=4, multiFeatures=False, queryFeatures=False, condensed=True, hiddenTypes={'phrase','half_verse','subphrase', 'sentence', 'sentence_atom', 'clause', 'clause_atom'})
SP.show(results_SP, end=4, multiFeatures=False, queryFeatures=False, condensed=True, withNodes=False)
# Out:
#   0.50s 7 results
#   0.10s 7 results
# <p><b>verse</b> <i>1</i>
# ...

# %%
text = """
book book=Numbers|Numeri
    chapter chapter=6
        verse verse=13
            word
"""
results_MT = MT.search(f'{text}')
results_SP = SP.search(f'{text}')
MT.show(results_MT, end=4, multiFeatures=False, queryFeatures=False, condensed=True, hiddenTypes={'phrase','half_verse','subphrase', 'sentence', 'sentence_atom', 'clause', 'clause_atom'})
SP.show(results_SP, end=4, multiFeatures=False, queryFeatures=False, condensed=True, withNodes=False)
# Out:
#   0.18s 16 results
#   0.10s 16 results
# <p><b>verse</b> <i>1</i>
# ...

# %%
text = """
book book=Numbers|Numeri
    chapter chapter=7
        verse verse=30
            word
"""
results_MT = MT.search(f'{text}')
results_SP = SP.search(f'{text}')
MT.show(results_MT, end=4, multiFeatures=False, queryFeatures=False, condensed=True, hiddenTypes={'phrase','half_verse','subphrase', 'sentence', 'sentence_atom', 'clause', 'clause_atom'})
SP.show(results_SP, end=4, multiFeatures=False, queryFeatures=False, condensed=True, withNodes=False)
# Out:
#   0.18s 12 results
#   0.09s 11 results
# <p><b>verse</b> <i>1</i>
# ...

# %%
text = """
book book=Numbers|Numeri
    chapter chapter=10
        verse verse=16
            word
"""
results_MT = MT.search(f'{text}')
results_SP = SP.search(f'{text}')
MT.show(results_MT, end=4, multiFeatures=False, queryFeatures=False, condensed=True, hiddenTypes={'phrase','half_verse','subphrase', 'sentence', 'sentence_atom', 'clause', 'clause_atom'})
SP.show(results_SP, end=4, multiFeatures=False, queryFeatures=False, condensed=True, withNodes=False)
# Out:
#   0.53s 9 results
#   0.05s 9 results
# <p><b>verse</b> <i>1</i>
# ...

# %%
text = """
book book=Numbers|Numeri
    chapter chapter=14
        verse verse=30
            word
"""
results_MT = MT.search(f'{text}')
results_SP = SP.search(f'{text}')
MT.show(results_MT, end=4, multiFeatures=False, queryFeatures=False, condensed=True, hiddenTypes={'phrase','half_verse','subphrase', 'sentence', 'sentence_atom', 'clause', 'clause_atom'})
SP.show(results_SP, end=4, multiFeatures=False, queryFeatures=False, condensed=True, withNodes=False)
# Out:
#   0.50s 23 results
#   0.09s 23 results
# <p><b>verse</b> <i>1</i>
# ...

# %%
text = """
book book=Numbers|Numeri
    chapter chapter=20
        verse verse=4
            word
"""
results_MT = MT.search(f'{text}')
results_SP = SP.search(f'{text}')
MT.show(results_MT, end=4, multiFeatures=False, queryFeatures=False, condensed=True, hiddenTypes={'phrase','half_verse','subphrase', 'sentence', 'sentence_atom', 'clause', 'clause_atom'})
SP.show(results_SP, end=4, multiFeatures=False, queryFeatures=False, condensed=True, withNodes=False)
# Out:
#   0.49s 17 results
#   0.09s 17 results
# <p><b>verse</b> <i>1</i>
# ...

# %%
text = """
book book=Numbers|Numeri
    chapter chapter=22
        verse verse=16
            word
"""
results_MT = MT.search(f'{text}')
results_SP = SP.search(f'{text}')
MT.show(results_MT, end=4, multiFeatures=False, queryFeatures=False, condensed=True, hiddenTypes={'phrase','half_verse','subphrase', 'sentence', 'sentence_atom', 'clause', 'clause_atom'})
SP.show(results_SP, end=4, multiFeatures=False, queryFeatures=False, condensed=True, withNodes=False)
# Out:
#   0.53s 18 results
#   0.09s 18 results
# <p><b>verse</b> <i>1</i>
# ...

# %%
text = """
book book=Numbers|Numeri
    chapter chapter=23
        verse verse=17
            word
"""
results_MT = MT.search(f'{text}')
results_SP = SP.search(f'{text}')
MT.show(results_MT, end=4, multiFeatures=False, queryFeatures=False, condensed=True, hiddenTypes={'phrase','half_verse','subphrase', 'sentence', 'sentence_atom', 'clause', 'clause_atom'})
SP.show(results_SP, end=4, multiFeatures=False, queryFeatures=False, condensed=True, withNodes=False)
# Out:
#   0.50s 19 results
#   0.05s 19 results
# <p><b>verse</b> <i>1</i>
# ...

# %%
text = """
book book=Numbers|Numeri
    chapter chapter=26
        verse verse=31
            word
"""
results_MT = MT.search(f'{text}')
results_SP = SP.search(f'{text}')
MT.show(results_MT, end=4, multiFeatures=False, queryFeatures=False, condensed=True, hiddenTypes={'phrase','half_verse','subphrase', 'sentence', 'sentence_atom', 'clause', 'clause_atom'})
SP.show(results_SP, end=4, multiFeatures=False, queryFeatures=False, condensed=True, withNodes=False)
# Out:
#   0.50s 10 results
#   0.05s 10 results
# <p><b>verse</b> <i>1</i>
# ...

# %%
text = """
book book=Numbers|Numeri
    chapter chapter=31
        verse verse=53
            word
"""
results_MT = MT.search(f'{text}')
results_SP = SP.search(f'{text}')
MT.show(results_MT, end=4, multiFeatures=False, queryFeatures=False, condensed=True, hiddenTypes={'phrase','half_verse','subphrase', 'sentence', 'sentence_atom', 'clause', 'clause_atom'})
SP.show(results_SP, end=4, multiFeatures=False, queryFeatures=False, condensed=True, withNodes=False)
# Out:
#   0.19s 6 results
#   0.05s 6 results
# <p><b>verse</b> <i>1</i>
# ...

# %%
text = """
book book=Numbers|Numeri
    chapter chapter=33
        verse verse=1
            word
"""
results_MT = MT.search(f'{text}')
results_SP = SP.search(f'{text}')
MT.show(results_MT, end=4, multiFeatures=False, queryFeatures=False, condensed=True, hiddenTypes={'phrase','half_verse','subphrase', 'sentence', 'sentence_atom', 'clause', 'clause_atom'})
SP.show(results_SP, end=4, multiFeatures=False, queryFeatures=False, condensed=True, withNodes=False)
# Out:
#   0.60s 16 results
#   0.09s 16 results
# <p><b>verse</b> <i>1</i>
# ...

# %%
text = """
book book=Numbers|Numeri
    chapter chapter=33
        verse verse=31
            word
"""
results_MT = MT.search(f'{text}')
results_SP = SP.search(f'{text}')
MT.show(results_MT, end=4, multiFeatures=False, queryFeatures=False, condensed=True, hiddenTypes={'phrase','half_verse','subphrase', 'sentence', 'sentence_atom', 'clause', 'clause_atom'})
SP.show(results_SP, end=4, multiFeatures=False, queryFeatures=False, condensed=True, withNodes=False)
# Out:
#   0.18s 8 results
#   0.05s 8 results
# <p><b>verse</b> <i>1</i>
# ...

# %%
text = """
book book=Numbers|Numeri
    chapter chapter=34
        verse verse=5
            word
"""
results_MT = MT.search(f'{text}')
results_SP = SP.search(f'{text}')
MT.show(results_MT, end=4, multiFeatures=False, queryFeatures=False, condensed=True, hiddenTypes={'phrase','half_verse','subphrase', 'sentence', 'sentence_atom', 'clause', 'clause_atom'})
SP.show(results_SP, end=4, multiFeatures=False, queryFeatures=False, condensed=True, withNodes=False)
# Out:
#   0.27s 13 results
#   0.10s 13 results
# <p><b>verse</b> <i>1</i>
# ...

# %%
text = """
book book=Numbers|Numeri
    chapter chapter=35
        verse verse=3
            word
"""
results_MT = MT.search(f'{text}')
results_SP = SP.search(f'{text}')
MT.show(results_MT, end=4, multiFeatures=False, queryFeatures=False, condensed=True, hiddenTypes={'phrase','half_verse','subphrase', 'sentence', 'sentence_atom', 'clause', 'clause_atom'})
SP.show(results_SP, end=4, multiFeatures=False, queryFeatures=False, condensed=True, withNodes=False)
# Out:
#   0.51s 19 results
#   0.10s 19 results
# <p><b>verse</b> <i>1</i>
# ...
